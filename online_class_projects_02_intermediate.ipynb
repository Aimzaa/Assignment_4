# %% [markdown]
# <a href="https://colab.research.google.com/github/Aimzaa/Assignment_4/blob/main/online_class_projects_02_intermediate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import random
print("High Low Game")

round = 5

def main():
  print("Welcome to the High Low Game!")
  print("********************************")

  your_score = 0

  for i in range(round):
    print("Round", i + 1)

    computer_number: int = random.randint(1, 100)
    your_number: int = random.randint(1, 100)
    print("Your number is:", your_number)

    choice: str = input("Do you think your number is higher or lower than the computer's number? ")
    higher_and_correct:bool = choice == "higher" and your_number > computer_number
    lower_and_correct:bool = choice == "lower" and your_number < computer_number

    if higher_and_correct or lower_and_correct:
      print("You were right! The computer\'s number was",computer_number)
      your_score += 1
    else:
      print("That\'s incorrect! The computer\'s number was",computer_number)

    print("Your final score is", your_score)
    print()

  print("Thanks for playing!")

if __name__ == "__main__":
  main()
# Out:
# High Low Game
# Welcome to the High Low Game!
# ********************************
# Round 1
# Your number is: 56
# Do you think your number is higher or lower than the computer's number? higher
# You were right! The computer's number was 37
# Your final score is 1
#
# Round 2
# Your number is: 17
# Do you think your number is higher or lower than the computer's number? lower
# You were right! The computer's number was 74
# Your final score is 2
#
# Round 3
# Your number is: 48
# Do you think your number is higher or lower than the computer's number? higher
# You were right! The computer's number was 31
# Your final score is 3
#
# Round 4
# Your number is: 34
# Do you think your number is higher or lower than the computer's number? higher
# You were right! The computer's number was 13
# Your final score is 4
#
# Round 5
# Your number is: 50
# Do you think your number is higher or lower than the computer's number? lower
# That's incorrect! The computer's number was 44
# ...

# %%
print("Planetary Weight Calculator")

def main():
    print("\n Welcome to the Planetary Weight Calculator!")
    print("*******************************************")

    earth_weight = float(input("Enter your weight on Earth: "))

    gravity_ratios = {
        "Mercury": 0.38,
        "Venus": 0.91,
        "Mars": 0.38,
        "Jupiter": 2.34,
        "Saturn": 1.06,
        "Uranus": 0.92,
        "Neptune": 1.19,
    }

    print("\nSelect the planet")
    for planet in gravity_ratios:
        print(f'- {planet}')

    planet_choice = input("Enter the name of the planet: ").title()

    if planet_choice in gravity_ratios:
        new_weight = earth_weight * gravity_ratios[planet_choice]
        print(f"Your weight on {planet_choice} is {new_weight:.2f} kg.")
    else:
        print("Invalid planet choice.")

if __name__ == "__main__":
    main()
# Out:
# Planetary Weight Calculator
#
#  Welcome to the Planetary Weight Calculator!
# *******************************************
# Enter your weight on Earth: 50
#
# Select the planet
# - Mercury
# - Venus
# - Mars
# - Jupiter
# - Saturn
# - Uranus
# - Neptune
# Enter the name of the planet: saturn
# Your weight on Saturn is 53.00 kg.

# %%
print("\033[1;36m=== Lists and Dicts Game ===\033[0m")  # Cyan title

def access_element(my_list, index):
    if 0 <= index < len(my_list):
        return f"\033[1;32mElement at index {index}: {my_list[index]}\033[0m"  # Green success
    else:
        return "\033[1;31mError: Index out of range!\033[0m"  # Red error

def modify_element(my_list, index, new_value):
    if 0 <= index < len(my_list):
        my_list[index] = new_value
        return f"\033[1;32mUpdated list: {my_list}\033[0m"  # Green success
    else:
        return "\033[1;31mError: Index out of range!\033[0m"  # Red error

def slice_list(my_list, start, end):
    if 0 <= start < len(my_list) and 0 <= end <= len(my_list):
        return f"\033[1;34mSliced list: {my_list[start:end]}\033[0m"  # Blue slice
    else:
        return "\033[1;31mError: Invalid slice range!\033[0m"  # Red error

def list_game():
    print("\n\033[1;33mWelcome to the List Manipulation Game!\033[0m")  # Yellow welcome
    print("\033[1;35m************************\033[0m")  # Purple line

    my_list = ["apple", "mango", "banana", "orange", "cherry", "pineapple", "peach"]

    while True:
        print(f"\n\033[1mCurrent list:\033[0m {my_list}")  # Bold current list

        print("\n\033[1mSelect an option:\033[0m")  # Bold menu
        print("\033[1;36m1. Access an element\033[0m")  # Cyan option
        print("\033[1;36m2. Modify an element\033[0m")  # Cyan option
        print("\033[1;36m3. Slice a list\033[0m")  # Cyan option
        print("\033[1;31m4. Quit\033[0m")  # Red quit option

        choice = input("\n\033[1mEnter your choice (1-4): \033[0m")  # Bold prompt

        if choice == "1":
            index = int(input("Enter the index of the element you want to access: "))
            print(access_element(my_list, index))
        elif choice == "2":
            index = int(input("Enter the index of the element you want to modify: "))
            new_value = input("Enter the new value for the element: ")
            print(modify_element(my_list, index, new_value))
        elif choice == "3":
            start = int(input("Enter the starting index for the slice: "))
            end = int(input("Enter the ending index for the slice: "))
            print(slice_list(my_list, start, end))
        elif choice == "4":
            print("\033[1;33mThanks for playing! Goodbye!\033[0m")  # Yellow exit
            break
        else:
            print("\033[1;31mInvalid choice. Please enter 1, 2, 3, or 4.\033[0m")  # Red error

if __name__ == "__main__":
    list_game()
# Out:
# === Lists and Dicts Game ===
#
# Welcome to the List Manipulation Game!
# ************************
#
# Current list: ['apple', 'mango', 'banana', 'orange', 'cherry', 'pineapple', 'peach']
#
# Select an option:
# 1. Access an element
# 2. Modify an element
# 3. Slice a list
# 4. Quit
#
# Enter your choice (1-4): 1
# Enter the index of the element you want to access: 5
# Element at index 5: pineapple
#
# Current list: ['apple', 'mango', 'banana', 'orange', 'cherry', 'pineapple', 'peach']
#
# Select an option:
# 1. Access an element
# 2. Modify an element
# 3. Slice a list
# 4. Quit
#
# Enter your choice (1-4): 2
# Enter the index of the element you want to modify: 2
# Enter the new value for the element: kiwi
# Updated list: ['apple', 'mango', 'kiwi', 'orange', 'cherry', 'pineapple', 'peach']
#
# Current list: ['apple', 'mango', 'kiwi', 'orange', 'cherry', 'pineapple', 'peach']
#
# Select an option:
# 1. Access an element
# 2. Modify an element
# 3. Slice a list
# 4. Quit
#
# ...
